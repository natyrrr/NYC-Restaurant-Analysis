# %% [markdown]
# # **Eater NYC Data Frames**

# %%
# Import necessary libraries and dependencies.
import pandas as pd
from pathlib import Path
import csv
import sqlalchemy
from sqlalchemy import create_engine

# %%
# Import csv.
csv_path=Path("eater_closed_restaurants_data_raw")

# %%
data=pd.read_csv(csv_path)

# %%
# CSV Data Example.
data.head()
# Out:
#    restaurant_id           name   neighborhood    borough  zip_code  \
# 0              1  Awkward Scone       Bushwick   Brooklyn     11216
# 1              2   Kharian Deli        Chelsea  Manhattan     10011
# 2              3           Zauo        Chelsea  Manhattan     10011
# 3              4           Camp    Cobble Hill   Brooklyn     11201
# 4              5       Bunsmith  Crown Heights   Brooklyn     11238
#
#   closed_as_of_date
# 0        2020-08-06
# 1        2020-08-06
# 2        2020-08-06
# 3        2020-08-06
# 4        2020-08-06

# %%
# Import SQL grouped data frames by zip-code/income level.
# Create a connection to the database on my local PostgreSQL instance.
engine=create_engine("postgresql://postgres:postgres@localhost:5432/pandemic_eater_db")

# %%
# Create Query's for each SQL view I would like to make a DF here in Python.
query_low="SELECT*FROM low_income_closed_eater"

# %%
query_mid="SELECT*FROM mid_income_closed_eater"

# %%
query_high="SELECT*FROM high_income_closed_eater"

# %%
# Create Pandas DataFrames by reading records from the database.
low_income_df=pd.read_sql(query_low,engine)

# %%
# Low Income Data (There was none, therefore DF will be empty).
low_income_df
# Out:
# Empty DataFrame
# Columns: [restaurant_id, name, neighborhood, borough, zip_code, closed_as_of_date]
# Index: []

# %%
# Create low_income csv.
low_income_df.to_csv("low_income_closed.csv")

# %%
# Mid Income Data
mid_income_df=pd.read_sql(query_mid,engine)

# %%
mid_income_df
# Out:
#     restaurant_id                     name      neighborhood    borough  \
# 0               5                 Bunsmith     Crown Heights   Brooklyn
# 1               7                    Fonda      East Village  Manhattan
# 2               8                Oda House      East Village  Manhattan
# 3              43  Always and Forever Cafe          Bed Stuy   Brooklyn
# 4              45                 Bad Seed     Crown Heights   Brooklyn
# 5              53     Violet’s Bake Shoppe      Forest Hills     Queens
# 6              54     Dutch Kills Centraal  Long Island City     Queens
# 7              80                  Glady’s     Crown Heights   Brooklyn
# 8              91                the Finch      Clinton Hill   Brooklyn
# 9              96          The Way Station  Prospect Heights   Brooklyn
# 10            103            Urban Vintage      Clinton Hill   Brooklyn
# 11            104                   Violet      East Village  Manhattan
# ...

# %%
# Create mid_income csv.
mid_income_df.to_csv("mid_income_closed.csv")

# %%
# High Income Data.
high_income_df=pd.read_sql(query_high,engine)

# %%
high_income_df
# Out:
#     restaurant_id                          name     neighborhood    borough  \
# 0              16                   Holy Ground          Tribeca  Manhattan
# 1              17       Angkor Cambodian Bistro  Upper East Side  Manhattan
# 2              34               Agra Restaurant  Upper East Side  Manhattan
# 3              36                 La Caridad 78  Upper West Side  Manhattan
# 4              37                    Oath Pizza  Upper West Side  Manhattan
# 5              38                       Recolte  Upper West Side  Manhattan
# 6              44                   Let’s Makan        Chinatown  Manhattan
# 7              56                      Ali Baba  Upper West Side  Manhattan
# 8              57        Amsterdam Gourmet Deli  Upper West Side  Manhattan
# 9              58                the Beacon Bar  Upper West Side  Manhattan
# 10             60   Floating Mountain Tea House  Upper West Side  Manhattan
# ...

# %%
# Create high_income csv.
high_income_df.to_csv("high_income_closed.csv")
