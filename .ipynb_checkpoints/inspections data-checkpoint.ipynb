# %%
import pandas as pd
from pathlib import Path

# %%
csvpath= Path("Restaurant_grades.csv")
rest_grades_db= pd.read_csv(csvpath)
rest_grades_db.head()
# Out:
#                                      DBA       BORO BUILDING  \
# 0  EAT-A-BAGEL (JOHN A NOBLE FERRY BOAT)  Manhattan        0
# 1                    BROOKLYN SWEET SPOT   Brooklyn      366
# 2                    BROOKLYN SWEET SPOT   Brooklyn      366
# 3                    BROOKLYN SWEET SPOT   Brooklyn      366
# 4                    BROOKLYN SWEET SPOT   Brooklyn      366
#
#                      STREET  ZIPCODE CUISINE DESCRIPTION  \
# 0  WHITEHALL FERRY TERMINAL  10004.0            American
# 1             MYRTLE AVENUE  11205.0              Bakery
# 2             MYRTLE AVENUE  11205.0              Bakery
# 3             MYRTLE AVENUE  11205.0              Bakery
# 4             MYRTLE AVENUE  11205.0              Bakery
#
#                                VIOLATION DESCRIPTION CRITICAL FLAG  SCORE  \
# 0                                                NaN           NaN      0
# 1  Non-food contact surface improperly constructe...             N     10
# ...

# %%
rest_grades_db= rest_grades_db.drop(columns=['CUISINE DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE'])
rest_grades_db.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-4939833f6882> in <module>
# ----> 1 rest_grades_db= rest_grades_db.drop(columns=['CUISINE DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE'])
#       2 rest_grades_db.head()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
# ...

# %%
rest_grades_db.head()
# Out:
#                                      DBA       BORO BUILDING  \
# 0  EAT-A-BAGEL (JOHN A NOBLE FERRY BOAT)  Manhattan        0
# 1                    BROOKLYN SWEET SPOT   Brooklyn      366
# 2                    BROOKLYN SWEET SPOT   Brooklyn      366
# 3                    BROOKLYN SWEET SPOT   Brooklyn      366
# 4                    BROOKLYN SWEET SPOT   Brooklyn      366
#
#                      STREET  ZIPCODE  \
# 0  WHITEHALL FERRY TERMINAL  10004.0
# 1             MYRTLE AVENUE  11205.0
# 2             MYRTLE AVENUE  11205.0
# 3             MYRTLE AVENUE  11205.0
# 4             MYRTLE AVENUE  11205.0
#
#                                VIOLATION DESCRIPTION  GRADE DATE RECORD DATE
# 0                                                NaN  06/07/2013  08/07/2020
# 1  Non-food contact surface improperly constructe...  04/21/2014  08/07/2020
# 2  Personal cleanliness inadequate. Outer garment...  04/21/2014  08/07/2020
# ...

# %%
rest_grades_db= rest_grades_db.drop(columns=['VIOLATION DESCRIPTION'])
rest_grades_db.head()
# Out:
#                                      DBA       BORO BUILDING  \
# 0  EAT-A-BAGEL (JOHN A NOBLE FERRY BOAT)  Manhattan        0
# 1                    BROOKLYN SWEET SPOT   Brooklyn      366
# 2                    BROOKLYN SWEET SPOT   Brooklyn      366
# 3                    BROOKLYN SWEET SPOT   Brooklyn      366
# 4                    BROOKLYN SWEET SPOT   Brooklyn      366
#
#                      STREET  ZIPCODE  GRADE DATE RECORD DATE
# 0  WHITEHALL FERRY TERMINAL  10004.0  06/07/2013  08/07/2020
# 1             MYRTLE AVENUE  11205.0  04/21/2014  08/07/2020
# 2             MYRTLE AVENUE  11205.0  04/21/2014  08/07/2020
# 3             MYRTLE AVENUE  11205.0  10/30/2014  08/07/2020
# 4             MYRTLE AVENUE  11205.0  10/30/2014  08/07/2020

# %%
rest_grades_db= rest_grades_db.dropna().copy()
rest_grades_db.head()
# Out:
#                                      DBA       BORO BUILDING  \
# 0  EAT-A-BAGEL (JOHN A NOBLE FERRY BOAT)  Manhattan        0
# 1                    BROOKLYN SWEET SPOT   Brooklyn      366
# 2                    BROOKLYN SWEET SPOT   Brooklyn      366
# 3                    BROOKLYN SWEET SPOT   Brooklyn      366
# 4                    BROOKLYN SWEET SPOT   Brooklyn      366
#
#                      STREET  ZIPCODE  GRADE DATE RECORD DATE
# 0  WHITEHALL FERRY TERMINAL  10004.0  06/07/2013  08/07/2020
# 1             MYRTLE AVENUE  11205.0  04/21/2014  08/07/2020
# 2             MYRTLE AVENUE  11205.0  04/21/2014  08/07/2020
# 3             MYRTLE AVENUE  11205.0  10/30/2014  08/07/2020
# 4             MYRTLE AVENUE  11205.0  10/30/2014  08/07/2020
