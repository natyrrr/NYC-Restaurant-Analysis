# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
import plotly.express as px
import os
# %matplotlib inline

# %%
dateCols = ['GRADE DATE']
csvpath= Path("zipcode_restaurants_income.csv", parse_dates=dateCols)
pre_covid_db= pd.read_csv(csvpath)
pre_covid_db.head()
# Out:
#    New York    Borough  income_num_returns(households)  \
# 0     10007  Manhattan                            3640
# 1     10007  Manhattan                            3640
# 2     10007  Manhattan                            3640
# 3     10007  Manhattan                            3640
# 4     10007  Manhattan                            3640
#
#    avg income per return(x1000s) income level  \
# 0                     693.379945  high income
# 1                     693.379945  high income
# 2                     693.379945  high income
# 3                     693.379945  high income
# 4                     693.379945  high income
#
#                                DBA            STREET CUISINE DESCRIPTION  \
# 0            MARIACHI'S RESTAURANT   CHAMBERS STREET             Mexican
# 1            SPOTIFY - BARISTA BAR  GREENWICH STREET    Caf̩/Coffee/Tea
# 2  STARBUCKS COFFEE COMPANY #29854  GREENWICH STREET    Caf̩/Coffee/Tea
# 3            SPOTIFY - BARISTA BAR  GREENWICH STREET    Caf̩/Coffee/Tea
# 4                          CANTEEN   WORLD TRADE CTR            American
#
#    SCORE GRADE GRADE DATE
# 0     13     A  1/13/2020
# 1     13     A  1/22/2020
# 2      2     A  1/13/2020
# 3     13     A  1/22/2020
# 4     12     A  1/23/2020

# %%
Pre_restaurants= pre_covid_db.drop(columns=["CUISINE DESCRIPTION", "SCORE", "GRADE"])
Pre_restaurants.head(10)
# Out:
#    New York    Borough  income_num_returns(households)  \
# 0     10007  Manhattan                            3640
# 1     10007  Manhattan                            3640
# 2     10007  Manhattan                            3640
# 3     10007  Manhattan                            3640
# 4     10007  Manhattan                            3640
# 5     10007  Manhattan                            3640
# 6     10007  Manhattan                            3640
# 7     10007  Manhattan                            3640
# 8     10007  Manhattan                            3640
# 9     10007  Manhattan                            3640
#
#    avg income per return(x1000s) income level  \
# 0                     693.379945  high income
# 1                     693.379945  high income
# 2                     693.379945  high income
# 3                     693.379945  high income
# 4                     693.379945  high income
# 5                     693.379945  high income
# 6                     693.379945  high income
# 7                     693.379945  high income
# 8                     693.379945  high income
# 9                     693.379945  high income
#
#                                DBA            STREET  GRADE DATE
# 0            MARIACHI'S RESTAURANT   CHAMBERS STREET   1/13/2020
# 1            SPOTIFY - BARISTA BAR  GREENWICH STREET   1/22/2020
# 2  STARBUCKS COFFEE COMPANY #29854  GREENWICH STREET   1/13/2020
# 3            SPOTIFY - BARISTA BAR  GREENWICH STREET   1/22/2020
# 4                          CANTEEN   WORLD TRADE CTR   1/23/2020
# 5     JOE & THE JUICE GREENWICH ST  GREENWICH STREET  12/30/2019
# 6              BARCLAY STREET CAFE  GREENWICH STREET   1/10/2020
# 7     JOE & THE JUICE GREENWICH ST  GREENWICH STREET  12/30/2019
# 8                     LEKKA BURGER     WARREN STREET   1/10/2020
# 9                     LEKKA BURGER     WARREN STREET   1/10/2020

# %%
#Date_pre_db=Pre_restaurants.set_index(Pre_restaurants['GRADE DATE'])
#Date_pre_db.head()

# %%
#sorted_pre_restaurants= Date_pre_db.sort_index(ascending= True)
#sorted_pre_restaurants.head()

# %%
#pre_rest_db= sorted_pre_restaurants.loc['01/01/2019':'12/31/2019']
#pre_rest_db.head()

# %%
Pre_restaurants.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7         True
# 8        False
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14       False
# 15        True
# 16        True
# 17        True
# 18        True
# 19       False
# 20       False
# 21       False
# 22        True
# 23       False
# 24        True
# 25        True
# 26        True
# 27       False
# 28       False
# 29        True
#          ...
# 15679    False
# 15680    False
# 15681    False
# 15682    False
# 15683     True
# 15684    False
# 15685    False
# 15686     True
# 15687     True
# 15688    False
# 15689    False
# 15690     True
# 15691     True
# 15692     True
# 15693     True
# 15694     True
# 15695     True
# 15696     True
# 15697    False
# 15698     True
# 15699     True
# 15700     True
# 15701     True
# 15702     True
# 15703     True
# 15704     True
# 15705     True
# 15706     True
# 15707     True
# 15708     True
# Length: 15709, dtype: bool

# %%
Pre_restaurants= Pre_restaurants.drop_duplicates().copy()
Pre_restaurants.head()
# Out:
#    New York    Borough  income_num_returns(households)  \
# 0     10007  Manhattan                            3640
# 1     10007  Manhattan                            3640
# 2     10007  Manhattan                            3640
# 4     10007  Manhattan                            3640
# 5     10007  Manhattan                            3640
#
#    avg income per return(x1000s) income level  \
# 0                     693.379945  high income
# 1                     693.379945  high income
# 2                     693.379945  high income
# 4                     693.379945  high income
# 5                     693.379945  high income
#
#                                DBA            STREET  GRADE DATE
# 0            MARIACHI'S RESTAURANT   CHAMBERS STREET   1/13/2020
# 1            SPOTIFY - BARISTA BAR  GREENWICH STREET   1/22/2020
# 2  STARBUCKS COFFEE COMPANY #29854  GREENWICH STREET   1/13/2020
# 4                          CANTEEN   WORLD TRADE CTR   1/23/2020
# 5     JOE & THE JUICE GREENWICH ST  GREENWICH STREET  12/30/2019

# %%
Pre_restaurants['income level'].value_counts()
# Out:
# high income      3377
# medium income    1772
# low income       1337
# Name: income level, dtype: int64

# %%
Date_pre_db['New York'].value_counts()
# Out:
# 10013    1803
# 10022    1389
# 10017    1218
# 11101    1009
# 10009     940
# 11355     842
# 11238     802
# 11375     753
# 10028     602
# 10024     587
# 10023     553
# 10065     547
# 10021     516
# 10007     485
# 10453     442
# 10452     425
# 10454     333
# 10455     331
# 10457     295
# 10456     289
# 10075     259
# 10459     257
# 11357     230
# 10460     217
# 10309     215
# 11694     106
# 10464     102
# 10474      84
# 11360      59
# 10044      19
# Name: New York, dtype: int64

# %%
Date_pre_db["Borough"].value_counts()
# Out:
# Manhattan        8918
# Queens           2999
# Bronx            2775
# Brooklyn          802
# Staten Island     215
# Name: Borough, dtype: int64

# %%
# plotting

Date_pre_db["Borough"].value_counts().hvplot.bar(xlabel= 'Borough', ylabel= 'Number of Restaurants', label='Restaurants per Borough- 3/16/19- 8/6/19')
# Out:
# :Bars   [index]   (Borough)

# %%
Date_pre_db['income level'].value_counts().hvplot.bar(label= "Number of Restaurants in different Socio-Economic Areas, 3/16/19- 8/6/19", xlabel= "Income Bracket", ylabel= " # of Restaurants")
# Out:
# :Bars   [index]   (income level)
